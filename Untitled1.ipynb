# %%
import pandas as pd

# %%
data={
    "Ism":["Nozila","Marjona","Shohsanam","Shalola"],
    "Familiya":["Mirzakarimova","Isroilova","Mahmudjonova","Bekmirzayeva"],
    "Manzili":["Oqjar","Pakana","Azimobod","Begobod"],
    "Yoshi":[19,19,19,18],
    "Kursi":[2,2,2,2],
    "Jinsi":["ayol","ayol","ayol","ayol"]
}
baza=pd.DataFrame(data) #Pandas kutubxonasi uchun
print (baza)
# Out:
#          Ism       Familiya   Manzili  Yoshi  Kursi Jinsi
# 0     Nozila  Mirzakarimova     Oqjar     19      2  ayol
# 1    Marjona      Isroilova    Pakana     19      2  ayol
# 2  Shohsanam   Mahmudjonova  Azimobod     19      2  ayol
# 3    Shalola   Bekmirzayeva   Begobod     18      2  ayol
